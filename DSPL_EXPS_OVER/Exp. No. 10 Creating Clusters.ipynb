# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("C:\\Users\\kunal rajesh pitale\\Downloads\\flight2\\flights.csv")
data
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  DISTANCE  price  \
# 0       2019        2      4             1            1       867    595
# 1       2019        2      4             2            2       867    595
# 2       2019        2      4             3            3       867    556
# 3       2019        2      4             4            4       867    555
# 4       2019        2      4             5            5       867    555
# ...      ...      ...    ...           ...          ...       ...    ...
# 317218  2019        3      9            17            2      2306    444
# 317219  2019        3      9            17            2      2306    444
# 317220  2019        3      9            17            2      1721    444
# 317221  2019        3      9            16            1      1874    444
# 317222  2019        3      9            16            1      2306    444
#
#         class  airline  stops  departure_time  arrival_time  Delays
# ...

# %%
# Using K-Means Clustering
x = data.iloc[:,5:7] # 1st for rows and second for columns
x
# Out:
#         DISTANCE  price
# 0            867    595
# 1            867    595
# 2            867    556
# 3            867    555
# 4            867    555
# ...          ...    ...
# 317218      2306    444
# 317219      2306    444
# 317220      1721    444
# 317221      1874    444
# 317222      2306    444
#
# [317223 rows x 2 columns]

# %%
x= x.dropna()

kmeans = KMeans(2) # Creating two clusters
kmeans.fit(x)
# Out:
# KMeans(n_clusters=2)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([0, 0, 0, ..., 1, 1, 1])

# %%
data_with_clusters = data.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['DISTANCE'],data_with_clusters['price'],c=data_with_clusters['Clusters'],cmap='rainbow')
