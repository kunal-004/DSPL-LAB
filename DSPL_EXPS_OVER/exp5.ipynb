# %%
#import pandas
import pandas as pd
#import numpy
import numpy as np
#import matplotlib
import matplotlib.pyplot as plt
#import seaborn
import seaborn as sns

# %%
# use pandas to import csv file
df = pd.read_csv(r"C:\Users\karti\Downloads\newdata\flights.csv")
# too see max columns
pd.set_option('display.max_columns',None)
# print dataframe
df
# Out:
#         YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  DISTANCE  price  \
# 0       2019        2      4             1            1       867   5953
# 1       2019        2      4             2            2       867   5953
# 2       2019        2      4             3            3       867   5956
# 3       2019        2      4             4            4       867   5955
# 4       2019        2      4             5            5       867   5955
# ...      ...      ...    ...           ...          ...       ...    ...
# 317218  2019        3      9            17            2      2306  81585
# 317219  2019        3      9            17            2      2306  81585
# 317220  2019        3      9            17            2      1721  81585
# 317221  2019        3      9            16            1      1874  81585
# 317222  2019        3      9            16            1      2306  44444
#
#         class  airline  stops  departure_time  arrival_time Delays
# 0           1        1      0               3             4    Yes
# 1           1        1      0               1             1     No
# 2           1        2      0               1             1     No
# 3           1        3      0               1             2     No
# 4           1        3      0               1             1     No
# ...       ...      ...    ...             ...           ...    ...
# 317218      0        3      2               1             1     No
# 317219      0        3      2               1             1     No
# 317220      0        3      2               1             1     No
# 317221      0        3      1               1             1     No
# 317222      0        3      0               1             1    Yes
#
# [317223 rows x 13 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 317223 entries, 0 to 317222
# Data columns (total 13 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   YEAR            317223 non-null  int64
#  1   QUARTER         317223 non-null  int64
#  2   MONTH           317223 non-null  int64
#  3   DAY_OF_MONTH    317223 non-null  int64
#  4   DAY_OF_WEEK     317223 non-null  int64
#  5   DISTANCE        317223 non-null  int64
#  6   price           317223 non-null  int64
#  7   class           317223 non-null  int64
#  8   airline         317223 non-null  int64
#  9   stops           317223 non-null  int64
#  10  departure_time  317223 non-null  int64
#  11  arrival_time    317223 non-null  int64
#  12  Delays          317223 non-null  object
# dtypes: int64(12), object(1)
# memory usage: 31.5+ MB

# %%
#New dataframe 
new_df = df
#Checking for null values 
print(new_df.isnull().sum()) 
print("Missing values distribution: ")
print(new_df.isnull().mean())
# Out:
# YEAR              0
# QUARTER           0
# MONTH             0
# DAY_OF_MONTH      0
# DAY_OF_WEEK       0
# DISTANCE          0
# price             0
# class             0
# airline           0
# stops             0
# departure_time    0
# arrival_time      0
# Delays            0
# dtype: int64
# Missing values distribution:
# YEAR              0.0
# QUARTER           0.0
# MONTH             0.0
# DAY_OF_MONTH      0.0
# DAY_OF_WEEK       0.0
# DISTANCE          0.0
# price             0.0
# class             0.0
# airline           0.0
# stops             0.0
# departure_time    0.0
# arrival_time      0.0
# Delays            0.0
# dtype: float64

# %%
#New dataframe 
new_df = df
#Checking for null values 
print(new_df.isnull().sum()) 
print("Missing values distribution: ")
print(new_df.isnull().mean())
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64
# Missing values distribution:
# id                   0.0
# gender               0.0
# age                  0.0
# hypertension         0.0
# heart_disease        0.0
# ever_married         0.0
# work_type            0.0
# Residence_type       0.0
# avg_glucose_level    0.0
# bmi                  0.0
# smoking_status       0.0
# stroke               0.0
# dtype: float64

# %%
print(new_df.shape) 
print(new_df.head())
# Out:
# (317223, 13)
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  DISTANCE  price  class  \
# 0  2019        2      4             1            1       867   5953      1
# 1  2019        2      4             2            2       867   5953      1
# 2  2019        2      4             3            3       867   5956      1
# 3  2019        2      4             4            4       867   5955      1
# 4  2019        2      4             5            5       867   5955      1
#
#    airline  stops  departure_time  arrival_time Delays
# 0        1      0               3             4    Yes
# 1        1      0               1             1     No
# 2        2      0               1             1     No
# 3        3      0               1             2     No
# 4        3      0               1             1     No

# %%
new_df.Delays.value_counts()
plt.figure(figsize=(6,6))
sns.countplot(x='Delays', data=new_df)
plt.title('Flight delay')
plt.show()

# %%
#Describing data after preprocessing 
print(new_df.shape) 
print(new_df.head())
# Out:
# (317223, 13)
#    YEAR  QUARTER  MONTH  DAY_OF_MONTH  DAY_OF_WEEK  DISTANCE  price  class  \
# 0  2019        2      4             1            1       867   5953      1
# 1  2019        2      4             2            2       867   5953      1
# 2  2019        2      4             3            3       867   5956      1
# 3  2019        2      4             4            4       867   5955      1
# 4  2019        2      4             5            5       867   5955      1
#
#    airline  stops  departure_time  arrival_time Delays
# 0        1      0               3             4    Yes
# 1        1      0               1             1     No
# 2        2      0               1             1     No
# 3        3      0               1             2     No
# 4        3      0               1             1     No

# %%
from sklearn.datasets import make_classification
X, y = make_classification(n_classes=2, class_sep=0.5,
weights=[0.05, 0.95], n_informative=2, n_redundant=0, flip_y=0,
n_features=2, n_clusters_per_class=1, n_samples=1000, random_state=10)

# %%
from sklearn.model_selection import train_test_split
  
# split into 70:30 ration
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 0)

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
X_res, y_res = sm.fit_resample(X_train, y_train)

# %%
# describes info about train and test set
print("Number transactions X_train dataset: ", X_train.shape)
print("Number transactions y_train dataset: ", y_train.shape)
print("Number transactions X_test dataset: ", X_test.shape)
print("Number transactions y_test dataset: ", y_test.shape)
# Out:
# Number transactions X_train dataset:  (700, 2)
# Number transactions y_train dataset:  (700,)
# Number transactions X_test dataset:  (300, 2)
# Number transactions y_test dataset:  (300,)
